# %% [markdown]
# <a href="https://colab.research.google.com/github/JaesungJung24/VegetableImageClassification/blob/main/Landmarks_Image_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image classification
# _

# %% [markdown]
# This tutorial shows how to classify images of flowers. It creates an image classifier using a `tf.keras.Sequential` model, and loads data using `tf.keras.utils.image_dataset_from_directory`. You will gain practical experience with the following concepts:
#
# * Efficiently loading a dataset off disk.
# * Identifying overfitting and applying techniques to mitigate it, including data augmentation and dropout.
#
# This tutorial follows a basic machine learning workflow:
#
# 1. Examine and understand data
# 2. Build an input pipeline
# 3. Build the model
# 4. Train the model
# 5. Test the model
# 6. Improve the model and repeat the process

# %% [markdown]
# ## Import TensorFlow and other libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Download and explore the dataset

# %% [markdown]
# This tutorial uses a dataset of about 3,700 photos of flowers. The dataset contains five sub-directories, one per class:
#
# ```
# flower_photo/
#   daisy/
#   dandelion/
#   roses/
#   sunflowers/
#   tulips/
# ```

# %%
import pathlib
# dataset_url = "https://drive.google.com/file/d/1pjVbza48McG5rpcrvtUsDjKYX_b-7WlI/view?usp=sharing"
# data_dir = tf.keras.utils.get_file('landmarks_photos', origin=dataset_url, untar=True)
data_dir = '/content/drive/MyDrive/Jae Sung/Image Classification/wonder_dataset/Wonders of World'
data_dir = pathlib.Path(data_dir)

# %%
data_dir
# Out:
# PosixPath('/content/drive/MyDrive/Jae Sung/Image Classification/wonder_dataset/Wonders of World')

# %% [markdown]
# After downloading, you should now have a copy of the dataset available. There are 3,670 total images:

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3846

# %% [markdown]
# Here are some roses:

# %%
burf_khalifa = list(data_dir.glob('burj_khalifa/*'))
PIL.Image.open(str(burf_khalifa[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=194x259 at 0x7F8532A7D810>

# %%
PIL.Image.open(str(burf_khalifa[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=385x600 at 0x7F8535D98550>

# %% [markdown]
# And some tulips:

# %%
chichen_itza = list(data_dir.glob('chichen_itza/*'))
PIL.Image.open(str(chichen_itza[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=630x315 at 0x7F85A8951890>

# %%
PIL.Image.open(str(chichen_itza[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x7F8532A52890>

# %% [markdown]
# # Load data using a Keras utility
#
# Let's load these images off disk using the helpful `tf.keras.utils.image_dataset_from_directory` utility. This will take you from a directory of images on disk to a `tf.data.Dataset` in just a couple lines of code.

# %% [markdown]
# ## Create a dataset

# %% [markdown]
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# It's good practice to use a validation split when developing your model. Let's use 80% of the images for training, and 20% for validation.

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3846 files belonging to 12 classes.
# Using 3077 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3846 files belonging to 12 classes.
# Using 769 files for validation.

# %% [markdown]
# You can find the class names in the `class_names` attribute on these datasets. These correspond to the directory names in alphabetical order.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['burj_khalifa', 'chichen_itza', 'christ_the_reedemer', 'eiffel_tower', 'great_wall_of_china', 'machu_pichu', 'pyramids_of_giza', 'roman_colosseum', 'statue_of_liberty', 'stonehenge', 'taj_mahal', 'venezuela_angel_falls']

# %% [markdown]
# ## Visualize the data
#
# Here are the first nine images from the training dataset:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# You will train a model using these datasets by passing them to `Model.fit` in a moment. If you like, you can also manually iterate over the dataset and retrieve batches of images:

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.
#
# You can call `.numpy()` on the `image_batch` and `labels_batch` tensors to convert them to a `numpy.ndarray`.

# %% [markdown]
# ## Configure the dataset for performance
#
# Let's make sure to use buffered prefetching so you can yield data from disk without having I/O become blocking. These are two important methods you should use when loading data:
#
# - `Dataset.cache` keeps the images in memory after they're loaded off disk during the first epoch. This will ensure the dataset does not become a bottleneck while training your model. If your dataset is too large to fit into memory, you can also use this method to create a performant on-disk cache.
# - `Dataset.prefetch` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Standardize the data

# %% [markdown]
# The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network; in general you should seek to make your input values small.
#
# Here, you will standardize values to be in the `[0, 1]` range by using `tf.keras.layers.Rescaling`:

# %%
normalization_layer = layers.Rescaling(1./255)

# %% [markdown]
# There are two ways to use this layer. You can apply it to the dataset by calling `Dataset.map`:

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 0.999216

# %% [markdown]
# Note: You previously resized images using the `image_size` argument of `tf.keras.utils.image_dataset_from_directory`. If you want to include the resizing logic in your model as well, you can use the `tf.keras.layers.Resizing` layer.

# %% [markdown]
# # Create the model
#
# The [Sequential](https://www.tensorflow.org/guide/keras/sequential_model) model consists of three convolution blocks (`tf.keras.layers.Conv2D`) with a max pooling layer (`tf.keras.layers.MaxPooling2D`) in each of them. There's a fully-connected layer (`tf.keras.layers.Dense`) with 128 units on top of it that is activated by a ReLU activation function (`'relu'`). This model has not been tuned for high accuracy—the goal of this tutorial is to show a standard approach.

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  #layers.Conv2D(64, 3, padding='same', activation='relu'),
  #layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ## Compile the model
#
# For this tutorial, choose the `tf.keras.optimizers.Adam` optimizer and `tf.keras.losses.SparseCategoricalCrossentropy` loss function. To view training and validation accuracy for each training epoch, pass the `metrics` argument to `Model.compile`.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ## Model summary
#
# View all the layers of the network using the model's `Model.summary` method:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 64800)             0
#
#  dense (Dense)               (None, 128)               8294528
#
#  dense_1 (Dense)             (None, 12)                1548
#
# =================================================================
# Total params: 8,301,164
# Trainable params: 8,301,164
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 97/97 [==============================] - 169s 2s/step - loss: 2.1876 - accuracy: 0.3110 - val_loss: 1.6292 - val_accuracy: 0.4668
# Epoch 2/10
# 97/97 [==============================] - 1s 15ms/step - loss: 1.2293 - accuracy: 0.5983 - val_loss: 1.2725 - val_accuracy: 0.5722
# Epoch 3/10
# 97/97 [==============================] - 1s 15ms/step - loss: 0.6424 - accuracy: 0.8112 - val_loss: 0.9318 - val_accuracy: 0.7074
# Epoch 4/10
# 97/97 [==============================] - 1s 14ms/step - loss: 0.2693 - accuracy: 0.9275 - val_loss: 0.8764 - val_accuracy: 0.7555
# Epoch 5/10
# 97/97 [==============================] - 1s 14ms/step - loss: 0.1049 - accuracy: 0.9766 - val_loss: 1.0057 - val_accuracy: 0.7412
# Epoch 6/10
# 97/97 [==============================] - 1s 15ms/step - loss: 0.0505 - accuracy: 0.9906 - val_loss: 0.8237 - val_accuracy: 0.7971
# Epoch 7/10
# 97/97 [==============================] - 1s 15ms/step - loss: 0.0147 - accuracy: 0.9984 - val_loss: 0.8810 - val_accuracy: 0.7997
# Epoch 8/10
# 97/97 [==============================] - 1s 14ms/step - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.8907 - val_accuracy: 0.8166
# Epoch 9/10
# 97/97 [==============================] - 1s 15ms/step - loss: 0.0036 - accuracy: 0.9997 - val_loss: 0.9570 - val_accuracy: 0.8010
# Epoch 10/10
# 97/97 [==============================] - 1s 15ms/step - loss: 0.0125 - accuracy: 0.9984 - val_loss: 0.9412 - val_accuracy: 0.8114

# %% [markdown]
# ## Visualize training results

# %% [markdown]
# Create plots of loss and accuracy on the training and validation sets:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# The plots show that training accuracy and validation accuracy are off by large margins, and the model has achieved only around 60% accuracy on the validation set.
#
# Let's inspect what went wrong and try to increase the overall performance of the model.

# %% [markdown]
# ## Overfitting

# %% [markdown]
# In the plots above, the training accuracy is increasing linearly over time, whereas validation accuracy stalls around 60% in the training process. Also, the difference in accuracy between training and validation accuracy is noticeable—a sign of [overfitting](https://www.tensorflow.org/tutorials/keras/overfit_and_underfit).
#
# When there are a small number of training examples, the model sometimes learns from noises or unwanted details from training examples—to an extent that it negatively impacts the performance of the model on new examples. This phenomenon is known as overfitting. It means that the model will have a difficult time generalizing on a new dataset.
#
# There are multiple ways to fight overfitting in the training process. In this tutorial, you'll use *data augmentation* and add *Dropout* to your model.

# %% [markdown]
# ## Data augmentation

# %% [markdown]
# Overfitting generally occurs when there are a small number of training examples. [Data augmentation](./data_augmentation.ipynb) takes the approach of generating additional training data from your existing examples by augmenting them using random transformations that yield believable-looking images. This helps expose the model to more aspects of the data and generalize better.
#
# You will implement data augmentation using the following Keras preprocessing layers: `tf.keras.layers.RandomFlip`, `tf.keras.layers.RandomRotation`, and `tf.keras.layers.RandomZoom`. These can be included inside your model like other layers, and run on the GPU.

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast([0.9, 1.1]),
  ]
)

# %% [markdown]
# Let's visualize what a few augmented examples look like by applying data augmentation to the same image several times:

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# You will use data augmentation to train a model in a moment.

# %% [markdown]
# ## Dropout
#
# Another technique to reduce overfitting is to introduce [dropout](https://developers.google.com/machine-learning/glossary#dropout_regularization) regularization to the network.
#
# When you apply dropout to a layer, it randomly drops out (by setting the activation to zero) a number of output units from the layer during the training process. Dropout takes a fractional number as its input value, in the form such as 0.1, 0.2, 0.4, etc. This means dropping out 10%, 20% or 40% of the output units randomly from the applied layer.
#
# Let's create a new neural network with `tf.keras.layers.Dropout` before training it using the augmented images:

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ## Compile and train the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_2 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_2 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_3 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 45, 45, 32)        9248
#
#  max_pooling2d_4 (MaxPooling  (None, 22, 22, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 22, 22, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_6 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  dropout (Dropout)           (None, 5, 5, 64)          0
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dense_2 (Dense)             (None, 128)               204928
#
#  dense_3 (Dense)             (None, 12)                1548
#
# =================================================================
# Total params: 276,236
# Trainable params: 276,236
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 60
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/80
# 97/97 [==============================] - 3s 21ms/step - loss: 2.4366 - accuracy: 0.1313 - val_loss: 2.2660 - val_accuracy: 0.1847
# Epoch 2/80
# 97/97 [==============================] - 2s 19ms/step - loss: 2.2461 - accuracy: 0.2031 - val_loss: 2.0931 - val_accuracy: 0.2744
# Epoch 3/80
# 97/97 [==============================] - 2s 19ms/step - loss: 2.0883 - accuracy: 0.2675 - val_loss: 1.8834 - val_accuracy: 0.3329
# Epoch 4/80
# 97/97 [==============================] - 2s 19ms/step - loss: 1.8863 - accuracy: 0.3448 - val_loss: 1.7062 - val_accuracy: 0.4200
# Epoch 5/80
# 97/97 [==============================] - 2s 19ms/step - loss: 1.8278 - accuracy: 0.3679 - val_loss: 1.6187 - val_accuracy: 0.4265
# Epoch 6/80
# 97/97 [==============================] - 2s 19ms/step - loss: 1.6806 - accuracy: 0.4261 - val_loss: 1.6743 - val_accuracy: 0.4122
# Epoch 7/80
# 97/97 [==============================] - 2s 21ms/step - loss: 1.6317 - accuracy: 0.4410 - val_loss: 1.4303 - val_accuracy: 0.5085
# Epoch 8/80
# 97/97 [==============================] - 2s 19ms/step - loss: 1.5744 - accuracy: 0.4703 - val_loss: 1.4018 - val_accuracy: 0.5241
# Epoch 9/80
# 97/97 [==============================] - 2s 19ms/step - loss: 1.5384 - accuracy: 0.4751 - val_loss: 1.2726 - val_accuracy: 0.5631
# Epoch 10/80
# 97/97 [==============================] - 2s 19ms/step - loss: 1.4376 - accuracy: 0.5291 - val_loss: 1.2086 - val_accuracy: 0.5865
# Epoch 11/80
# 97/97 [==============================] - 2s 19ms/step - loss: 1.4128 - accuracy: 0.5255 - val_loss: 1.2418 - val_accuracy: 0.5774
# Epoch 12/80
# 97/97 [==============================] - 2s 19ms/step - loss: 1.3187 - accuracy: 0.5541 - val_loss: 1.2675 - val_accuracy: 0.5735
# Epoch 13/80
# 97/97 [==============================] - 2s 19ms/step - loss: 1.3284 - accuracy: 0.5593 - val_loss: 1.2407 - val_accuracy: 0.5709
# Epoch 14/80
# 97/97 [==============================] - 2s 19ms/step - loss: 1.2637 - accuracy: 0.5808 - val_loss: 1.2403 - val_accuracy: 0.5852
# Epoch 15/80
# 97/97 [==============================] - 2s 19ms/step - loss: 1.2043 - accuracy: 0.5993 - val_loss: 1.1898 - val_accuracy: 0.5969
# Epoch 16/80
# 97/97 [==============================] - 2s 19ms/step - loss: 1.2207 - accuracy: 0.5882 - val_loss: 1.1698 - val_accuracy: 0.6164
# Epoch 17/80
# 97/97 [==============================] - 2s 19ms/step - loss: 1.1002 - accuracy: 0.6367 - val_loss: 1.0413 - val_accuracy: 0.6411
# Epoch 18/80
# 97/97 [==============================] - 2s 19ms/step - loss: 1.1372 - accuracy: 0.6263 - val_loss: 0.9694 - val_accuracy: 0.6593
# Epoch 19/80
# 97/97 [==============================] - 2s 19ms/step - loss: 1.0811 - accuracy: 0.6435 - val_loss: 1.0636 - val_accuracy: 0.6450
# Epoch 20/80
# 97/97 [==============================] - 2s 19ms/step - loss: 1.0743 - accuracy: 0.6422 - val_loss: 1.0261 - val_accuracy: 0.6593
# Epoch 21/80
# 97/97 [==============================] - 2s 19ms/step - loss: 1.0812 - accuracy: 0.6328 - val_loss: 1.0276 - val_accuracy: 0.6645
# Epoch 22/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.9467 - accuracy: 0.6857 - val_loss: 0.8782 - val_accuracy: 0.7191
# Epoch 23/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.9937 - accuracy: 0.6724 - val_loss: 0.8938 - val_accuracy: 0.7035
# Epoch 24/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.9163 - accuracy: 0.6903 - val_loss: 0.9295 - val_accuracy: 0.6918
# Epoch 25/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.9101 - accuracy: 0.7026 - val_loss: 0.8459 - val_accuracy: 0.7243
# Epoch 26/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.8851 - accuracy: 0.7169 - val_loss: 0.8106 - val_accuracy: 0.7360
# Epoch 27/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.8222 - accuracy: 0.7169 - val_loss: 0.8331 - val_accuracy: 0.7542
# Epoch 28/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.8517 - accuracy: 0.7085 - val_loss: 0.8021 - val_accuracy: 0.7295
# Epoch 29/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.8026 - accuracy: 0.7319 - val_loss: 0.8621 - val_accuracy: 0.7152
# Epoch 30/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.7778 - accuracy: 0.7439 - val_loss: 0.8325 - val_accuracy: 0.7295
# Epoch 31/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.7605 - accuracy: 0.7449 - val_loss: 0.7713 - val_accuracy: 0.7568
# Epoch 32/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.7959 - accuracy: 0.7319 - val_loss: 0.7475 - val_accuracy: 0.7516
# Epoch 33/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.7539 - accuracy: 0.7439 - val_loss: 0.6915 - val_accuracy: 0.7867
# Epoch 34/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.7012 - accuracy: 0.7670 - val_loss: 0.7838 - val_accuracy: 0.7568
# Epoch 35/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.7499 - accuracy: 0.7462 - val_loss: 0.6899 - val_accuracy: 0.7906
# Epoch 36/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.6847 - accuracy: 0.7741 - val_loss: 0.7231 - val_accuracy: 0.7620
# Epoch 37/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.6109 - accuracy: 0.8044 - val_loss: 0.6861 - val_accuracy: 0.7893
# Epoch 38/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.6067 - accuracy: 0.7940 - val_loss: 0.6591 - val_accuracy: 0.7919
# Epoch 39/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.6374 - accuracy: 0.7875 - val_loss: 0.7457 - val_accuracy: 0.7685
# Epoch 40/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.6767 - accuracy: 0.7764 - val_loss: 0.6567 - val_accuracy: 0.7932
# Epoch 41/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.5912 - accuracy: 0.8044 - val_loss: 0.7033 - val_accuracy: 0.7828
# Epoch 42/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.5764 - accuracy: 0.8125 - val_loss: 0.6181 - val_accuracy: 0.7984
# Epoch 43/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.5432 - accuracy: 0.8187 - val_loss: 0.6152 - val_accuracy: 0.8140
# Epoch 44/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.5857 - accuracy: 0.8050 - val_loss: 0.6157 - val_accuracy: 0.8088
# Epoch 45/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.5621 - accuracy: 0.8167 - val_loss: 0.6262 - val_accuracy: 0.8036
# Epoch 46/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.5534 - accuracy: 0.8060 - val_loss: 0.6639 - val_accuracy: 0.7893
# Epoch 47/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.5442 - accuracy: 0.8164 - val_loss: 0.7098 - val_accuracy: 0.7828
# Epoch 48/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.5683 - accuracy: 0.8118 - val_loss: 0.6174 - val_accuracy: 0.8309
# Epoch 49/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.5493 - accuracy: 0.8164 - val_loss: 0.7016 - val_accuracy: 0.8075
# Epoch 50/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.6244 - accuracy: 0.7959 - val_loss: 0.5909 - val_accuracy: 0.8296
# Epoch 51/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.4461 - accuracy: 0.8512 - val_loss: 0.6342 - val_accuracy: 0.8296
# Epoch 52/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.4748 - accuracy: 0.8466 - val_loss: 0.7105 - val_accuracy: 0.7906
# Epoch 53/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.5116 - accuracy: 0.8281 - val_loss: 0.6391 - val_accuracy: 0.8466
# Epoch 54/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.4747 - accuracy: 0.8424 - val_loss: 0.6639 - val_accuracy: 0.8231
# Epoch 55/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.5280 - accuracy: 0.8170 - val_loss: 0.6514 - val_accuracy: 0.8192
# Epoch 56/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.4545 - accuracy: 0.8499 - val_loss: 0.5761 - val_accuracy: 0.8414
# Epoch 57/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.5116 - accuracy: 0.8271 - val_loss: 0.6450 - val_accuracy: 0.8440
# Epoch 58/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.4875 - accuracy: 0.8349 - val_loss: 0.5284 - val_accuracy: 0.8544
# Epoch 59/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.4577 - accuracy: 0.8508 - val_loss: 0.6716 - val_accuracy: 0.8010
# Epoch 60/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.4818 - accuracy: 0.8375 - val_loss: 0.7303 - val_accuracy: 0.8153
# Epoch 61/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.4269 - accuracy: 0.8564 - val_loss: 0.6711 - val_accuracy: 0.8283
# Epoch 62/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.4972 - accuracy: 0.8307 - val_loss: 0.5889 - val_accuracy: 0.8231
# Epoch 63/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.4428 - accuracy: 0.8538 - val_loss: 0.5103 - val_accuracy: 0.8674
# Epoch 64/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.4418 - accuracy: 0.8547 - val_loss: 0.5938 - val_accuracy: 0.8322
# Epoch 65/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.4715 - accuracy: 0.8424 - val_loss: 0.7530 - val_accuracy: 0.8179
# Epoch 66/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.4327 - accuracy: 0.8538 - val_loss: 0.5752 - val_accuracy: 0.8609
# Epoch 67/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.4514 - accuracy: 0.8486 - val_loss: 0.6057 - val_accuracy: 0.8440
# Epoch 68/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.4217 - accuracy: 0.8599 - val_loss: 0.5852 - val_accuracy: 0.8427
# Epoch 69/80
# 97/97 [==============================] - 2s 20ms/step - loss: 0.3771 - accuracy: 0.8768 - val_loss: 0.7133 - val_accuracy: 0.8427
# Epoch 70/80
# 97/97 [==============================] - 2s 20ms/step - loss: 0.4688 - accuracy: 0.8492 - val_loss: 0.5964 - val_accuracy: 0.8466
# Epoch 71/80
# 97/97 [==============================] - 2s 20ms/step - loss: 0.3918 - accuracy: 0.8700 - val_loss: 0.6456 - val_accuracy: 0.8492
# Epoch 72/80
# 97/97 [==============================] - 2s 20ms/step - loss: 0.3993 - accuracy: 0.8710 - val_loss: 0.5883 - val_accuracy: 0.8453
# Epoch 73/80
# 97/97 [==============================] - 2s 20ms/step - loss: 0.3896 - accuracy: 0.8668 - val_loss: 0.6319 - val_accuracy: 0.8440
# Epoch 74/80
# 97/97 [==============================] - 2s 20ms/step - loss: 0.4167 - accuracy: 0.8632 - val_loss: 0.5865 - val_accuracy: 0.8557
# Epoch 75/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.3842 - accuracy: 0.8791 - val_loss: 0.6838 - val_accuracy: 0.8270
# Epoch 76/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.3843 - accuracy: 0.8765 - val_loss: 0.5894 - val_accuracy: 0.8557
# Epoch 77/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.3856 - accuracy: 0.8749 - val_loss: 0.5822 - val_accuracy: 0.8479
# Epoch 78/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.3904 - accuracy: 0.8671 - val_loss: 0.5216 - val_accuracy: 0.8622
# Epoch 79/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.3828 - accuracy: 0.8671 - val_loss: 0.5823 - val_accuracy: 0.8583
# Epoch 80/80
# 97/97 [==============================] - 2s 19ms/step - loss: 0.3340 - accuracy: 0.8902 - val_loss: 0.6729 - val_accuracy: 0.8518

# %%
export_path = str("/content/drive/MyDrive/Jae Sung")+"/artifacts/name_of_your_model.h5"
model.save(export_path, save_format='h5')

# %% [markdown]
# ## Visualize training results
#
# After applying data augmentation and `tf.keras.layers.Dropout`, there is less overfitting than before, and training and validation accuracy are closer aligned:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Predict on new data

# %% [markdown]
# Finally, let's use our model to classify an image that wasn't included in the training or validation sets.

# %% [markdown]
# Note: Data augmentation and dropout layers are inactive at inference time.

# %%
# sunflower_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/592px-Red_sunflower.jpg"
# sunflower_url = "https://www.gardeningknowhow.com/wp-content/uploads/2019/11/red-rose.jpg"




sunflower_path = tf.keras.utils.get_file('Red_sunflower', origin=sunflower_url)

# img = tf.keras.utils.load_img(
#     sunflower_path, target_size=(img_height, img_width)
# )
img = tf.keras.utils.load_img(
    str('/content/drive/MyDrive/Jae Sung/Image Classification/red-rose-on-black-background.jpg'), target_size=(img_height, img_width))
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-a62a4d5d43c2> in <module>
#       5
#       6
# ----> 7 sunflower_path = tf.keras.utils.get_file('Red_sunflower', origin=sunflower_url)
#       8
#       9 # img = tf.keras.utils.load_img(
#
# NameError: name 'sunflower_url' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
